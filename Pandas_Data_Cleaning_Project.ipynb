# %%
import pandas as pd

# %%
df = pd.read_csv("C:/Users/jsuri/Downloads/pandas/Employee performance and salary(practice).csv")

# %%
df
# Out:
#        ID   Age         Salary Department            Join_Date  \
# 0       1   NaN   39382.226945  Marketing          InvalidDate
# 1       2   NaN  105639.566878         HR          InvalidDate
# 2       3   NaN            NaN         HR  2014-04-08 16:37:06
# 3       4  27.0   41052.970366      Sales                  NaN
# 4       5   NaN   51231.543114      Sales                  NaN
# ..    ...   ...            ...        ...                  ...
# 995   996  27.0            NaN      Sales  2017-03-24 22:45:01
# 996   997  47.0   64883.570833        NaN          InvalidDate
# 997   998  50.0   71575.224300        NaN          InvalidDate
# 998   999  28.0  119242.956798        NaN  2004-02-27 14:55:17
# 999  1000   NaN            NaN         HR                  NaN
#
#     Has_Certification  Performance_Score              Rating  \
# 0                 NaN           5.000000                 NaN
# 1                True           2.000000                 NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID                 1000 non-null   int64
#  1   Age                510 non-null    float64
#  2   Salary             506 non-null    float64
#  3   Department         812 non-null    object
#  4   Join_Date          656 non-null    object
#  5   Has_Certification  701 non-null    object
#  6   Performance_Score  1000 non-null   float64
#  7   Rating             755 non-null    object
#  8   Experience_Years   663 non-null    float64
#  9   Remarks            753 non-null    object
# dtypes: float64(4), int64(1), object(5)
# memory usage: 78.3+ KB

# %%
df['Department'].value_counts()
# Out:
# Department
# HR           222
# IT           204
# Sales        198
# Marketing    188
# Name: count, dtype: int64

# %%
df['Age'].value_counts()
# Out:
# Age
# 52.0    22
# 25.0    18
# 43.0    18
# 21.0    18
# 20.0    17
# 59.0    17
# 54.0    17
# 56.0    16
# 45.0    16
# 24.0    15
# 27.0    15
# 44.0    15
# 55.0    15
# 41.0    14
# 22.0    14
# 51.0    14
# 31.0    14
# 37.0    13
# 42.0    13
# 39.0    13
# 33.0    13
# 23.0    13
# 47.0    12
# 28.0    12
# 48.0    11
# 34.0    11
# 58.0    11
# 50.0    11
# 32.0    10
# 40.0    10
# 49.0    10
# 36.0     9
# 30.0     9
# 29.0     9
# 53.0     9
# 38.0     9
# 35.0     9
# 26.0     8
# 46.0     5
# 57.0     5
# Name: count, dtype: int64

# %%
df['Age'] = df['Age'].astype('Int64')

# %%
df
# Out:
#        ID   Age         Salary Department            Join_Date  \
# 0       1  <NA>   39382.226945  Marketing          InvalidDate
# 1       2  <NA>  105639.566878         HR          InvalidDate
# 2       3  <NA>            NaN         HR  2014-04-08 16:37:06
# 3       4    27   41052.970366      Sales                  NaN
# 4       5  <NA>   51231.543114      Sales                  NaN
# ..    ...   ...            ...        ...                  ...
# 995   996    27            NaN      Sales  2017-03-24 22:45:01
# 996   997    47   64883.570833        NaN          InvalidDate
# 997   998    50   71575.224300        NaN          InvalidDate
# 998   999    28  119242.956798        NaN  2004-02-27 14:55:17
# 999  1000  <NA>            NaN         HR                  NaN
#
#     Has_Certification  Performance_Score              Rating  \
# 0                 NaN           5.000000                 NaN
# 1                True           2.000000                 NaN
# ...

# %%
df['Age'] = df['Age'].fillna(45).astype('int')

# %%
df
# Out:
#        ID  Age         Salary Department            Join_Date  \
# 0       1   45   39382.226945  Marketing          InvalidDate
# 1       2   45  105639.566878         HR          InvalidDate
# 2       3   45            NaN         HR  2014-04-08 16:37:06
# 3       4   27   41052.970366      Sales                  NaN
# 4       5   45   51231.543114      Sales                  NaN
# ..    ...  ...            ...        ...                  ...
# 995   996   27            NaN      Sales  2017-03-24 22:45:01
# 996   997   47   64883.570833        NaN          InvalidDate
# 997   998   50   71575.224300        NaN          InvalidDate
# 998   999   28  119242.956798        NaN  2004-02-27 14:55:17
# 999  1000   45            NaN         HR                  NaN
#
#     Has_Certification  Performance_Score              Rating  \
# 0                 NaN           5.000000                 NaN
# 1                True           2.000000                 NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID                 1000 non-null   int64
#  1   Age                1000 non-null   int32
#  2   Salary             506 non-null    float64
#  3   Department         812 non-null    object
#  4   Join_Date          656 non-null    object
#  5   Has_Certification  701 non-null    object
#  6   Performance_Score  1000 non-null   float64
#  7   Rating             755 non-null    object
#  8   Experience_Years   663 non-null    float64
#  9   Remarks            753 non-null    object
# dtypes: float64(3), int32(1), int64(1), object(5)
# memory usage: 74.3+ KB

# %%
df[(df['Age'] > 45) & (df['Department'] == 'HR')].head()
# Out:
#       ID  Age        Salary Department            Join_Date Has_Certification  \
# 11    12   55           NaN         HR          InvalidDate             False
# 27    28   47  52340.379848         HR                  NaN              True
# 92    93   58           NaN         HR          InvalidDate             False
# 133  134   48           NaN         HR  2000-09-16 23:10:13              True
# 143  144   47  95896.612061         HR  2000-11-07 10:01:51               NaN
#
#      Performance_Score              Rating  Experience_Years  \
# 11            9.433819                Good         37.000000
# 27            8.000000  1.8311336838467658         38.000000
# 92            7.192400                Good         28.000000
# 133           4.000000                Good               NaN
# 143           2.232992                Poor         27.754526
#
#                Remarks
# 11   Needs Improvement
# 27                 NaN
# 92                 NaN
# 133                NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID                 1000 non-null   int64
#  1   Age                1000 non-null   int32
#  2   Salary             506 non-null    float64
#  3   Department         812 non-null    object
#  4   Join_Date          656 non-null    object
#  5   Has_Certification  701 non-null    object
#  6   Performance_Score  1000 non-null   float64
#  7   Rating             755 non-null    object
#  8   Experience_Years   663 non-null    float64
#  9   Remarks            753 non-null    object
# dtypes: float64(3), int32(1), int64(1), object(5)
# memory usage: 74.3+ KB

# %%
df['Salary'].value_counts()
# Out:
# Salary
# 39382.226945     1
# 81946.671304     1
# 83683.692749     1
# 79364.974949     1
# 80709.503461     1
#                 ..
# 78940.101720     1
# 89590.080910     1
# 76447.111840     1
# 119232.780163    1
# 119242.956798    1
# Name: count, Length: 506, dtype: int64

# %%
df['Salary'] = df['Salary'].round(2)

# %%
df
# Out:
#        ID  Age     Salary Department            Join_Date Has_Certification  \
# 0       1   45   39382.23  Marketing          InvalidDate               NaN
# 1       2   45  105639.57         HR          InvalidDate              True
# 2       3   45        NaN         HR  2014-04-08 16:37:06               NaN
# 3       4   27   41052.97      Sales                  NaN              True
# 4       5   45   51231.54      Sales                  NaN               NaN
# ..    ...  ...        ...        ...                  ...               ...
# 995   996   27        NaN      Sales  2017-03-24 22:45:01               NaN
# 996   997   47   64883.57        NaN          InvalidDate               NaN
# 997   998   50   71575.22        NaN          InvalidDate               NaN
# 998   999   28  119242.96        NaN  2004-02-27 14:55:17             False
# 999  1000   45        NaN         HR                  NaN               NaN
#
# ...

# %%
df['Salary'].isnull().sum()
# Out:
# 494

# %%
df['Department'].value_counts()
# Out:
# Department
# HR           222
# IT           204
# Sales        198
# Marketing    188
# Name: count, dtype: int64

# %%
df['Department']= df['Department'].fillna('HR')

# %%
df
# Out:
#        ID  Age     Salary Department            Join_Date Has_Certification  \
# 0       1   45   39382.23  Marketing          InvalidDate               NaN
# 1       2   45  105639.57         HR          InvalidDate              True
# 2       3   45        NaN         HR  2014-04-08 16:37:06               NaN
# 3       4   27   41052.97      Sales                  NaN              True
# 4       5   45   51231.54      Sales                  NaN               NaN
# ..    ...  ...        ...        ...                  ...               ...
# 995   996   27        NaN      Sales  2017-03-24 22:45:01               NaN
# 996   997   47   64883.57         HR          InvalidDate               NaN
# 997   998   50   71575.22         HR          InvalidDate               NaN
# 998   999   28  119242.96         HR  2004-02-27 14:55:17             False
# 999  1000   45        NaN         HR                  NaN               NaN
#
# ...

# %%
df['Department'].value_counts().sum()
# Out:
# 1000

# %%
df['Salary'] = df['Salary'].fillna(method='ffill')
# Out:
# C:\Users\jsuri\AppData\Local\Temp\ipykernel_3860\2257056391.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['Salary'] = df['Salary'].fillna(method='ffill')

# %%
df
# Out:
#        ID  Age     Salary Department            Join_Date Has_Certification  \
# 0       1   45   39382.23  Marketing          InvalidDate               NaN
# 1       2   45  105639.57         HR          InvalidDate              True
# 2       3   45  105639.57         HR  2014-04-08 16:37:06               NaN
# 3       4   27   41052.97      Sales                  NaN              True
# 4       5   45   51231.54      Sales                  NaN               NaN
# ..    ...  ...        ...        ...                  ...               ...
# 995   996   27  102191.75      Sales  2017-03-24 22:45:01               NaN
# 996   997   47   64883.57         HR          InvalidDate               NaN
# 997   998   50   71575.22         HR          InvalidDate               NaN
# 998   999   28  119242.96         HR  2004-02-27 14:55:17             False
# 999  1000   45  119242.96         HR                  NaN               NaN
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID                 1000 non-null   int64
#  1   Age                1000 non-null   int32
#  2   Salary             1000 non-null   float64
#  3   Department         1000 non-null   object
#  4   Join_Date          656 non-null    object
#  5   Has_Certification  701 non-null    object
#  6   Performance_Score  1000 non-null   float64
#  7   Rating             755 non-null    object
#  8   Experience_Years   663 non-null    float64
#  9   Remarks            753 non-null    object
# dtypes: float64(3), int32(1), int64(1), object(5)
# memory usage: 74.3+ KB

# %%
df['Join_Date'].value_counts()
# Out:
# Join_Date
# InvalidDate            298
# 2008-10-20 14:27:45      1
# 2007-02-27 01:09:40      1
# 2014-09-13 23:44:59      1
# 2001-01-15 23:33:01      1
#                       ...
# 2022-07-24 16:44:04      1
# 2005-10-15 23:07:22      1
# 2008-05-01 09:37:58      1
# 2014-10-08 22:04:47      1
# 2004-02-27 14:55:17      1
# Name: count, Length: 359, dtype: int64

# %%
df['Join_Date'].value_counts().sum()
# Out:
# 656

# %%
df['Join_Date'] =pd.to_datetime(df['Join_Date'],errors = 'coerce')
# Out:
# C:\Users\jsuri\AppData\Local\Temp\ipykernel_3860\213581182.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Join_Date'] =pd.to_datetime(df['Join_Date'],errors = 'coerce')

# %%
df
# Out:
#        ID  Age     Salary Department           Join_Date Has_Certification  \
# 0       1   45   39382.23  Marketing                 NaT               NaN
# 1       2   45  105639.57         HR                 NaT              True
# 2       3   45  105639.57         HR 2014-04-08 16:37:06               NaN
# 3       4   27   41052.97      Sales                 NaT              True
# 4       5   45   51231.54      Sales                 NaT               NaN
# ..    ...  ...        ...        ...                 ...               ...
# 995   996   27  102191.75      Sales 2017-03-24 22:45:01               NaN
# 996   997   47   64883.57         HR                 NaT               NaN
# 997   998   50   71575.22         HR                 NaT               NaN
# 998   999   28  119242.96         HR 2004-02-27 14:55:17             False
# 999  1000   45  119242.96         HR                 NaT               NaN
#
#      Performance_Score              Rating  Experience_Years  \
# ...

# %%
df['Join_Date'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 1000 entries, 0 to 999
# Series name: Join_Date
# Non-Null Count  Dtype
# --------------  -----
# 358 non-null    datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 7.9 KB

# %%
df['Join_Date']=df['Join_Date'].fillna('2022-06-26')

# %%
df
# Out:
#        ID  Age     Salary Department           Join_Date Has_Certification  \
# 0       1   45   39382.23  Marketing 2022-06-26 00:00:00               NaN
# 1       2   45  105639.57         HR 2022-06-26 00:00:00              True
# 2       3   45  105639.57         HR 2014-04-08 16:37:06               NaN
# 3       4   27   41052.97      Sales 2022-06-26 00:00:00              True
# 4       5   45   51231.54      Sales 2022-06-26 00:00:00               NaN
# ..    ...  ...        ...        ...                 ...               ...
# 995   996   27  102191.75      Sales 2017-03-24 22:45:01               NaN
# 996   997   47   64883.57         HR 2022-06-26 00:00:00               NaN
# 997   998   50   71575.22         HR 2022-06-26 00:00:00               NaN
# 998   999   28  119242.96         HR 2004-02-27 14:55:17             False
# 999  1000   45  119242.96         HR 2022-06-26 00:00:00               NaN
#
#      Performance_Score              Rating  Experience_Years  \
# ...

# %%
df['Join_Date'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 1000 entries, 0 to 999
# Series name: Join_Date
# Non-Null Count  Dtype
# --------------  -----
# 1000 non-null   datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 7.9 KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID                 1000 non-null   int64
#  1   Age                1000 non-null   int32
#  2   Salary             1000 non-null   float64
#  3   Department         1000 non-null   object
#  4   Join_Date          1000 non-null   datetime64[ns]
#  5   Has_Certification  701 non-null    object
#  6   Performance_Score  1000 non-null   float64
#  7   Rating             755 non-null    object
#  8   Experience_Years   663 non-null    float64
#  9   Remarks            753 non-null    object
# dtypes: datetime64[ns](1), float64(3), int32(1), int64(1), object(4)
# memory usage: 74.3+ KB

# %%
df['Has_Certification'].value_counts()
# Out:
# Has_Certification
# True     365
# False    336
# Name: count, dtype: int64

# %%
df['Has_Certification']= df['Has_Certification'].fillna('True')

# %%
df
# Out:
#        ID  Age     Salary Department           Join_Date Has_Certification  \
# 0       1   45   39382.23  Marketing 2022-06-26 00:00:00              True
# 1       2   45  105639.57         HR 2022-06-26 00:00:00              True
# 2       3   45  105639.57         HR 2014-04-08 16:37:06              True
# 3       4   27   41052.97      Sales 2022-06-26 00:00:00              True
# 4       5   45   51231.54      Sales 2022-06-26 00:00:00              True
# ..    ...  ...        ...        ...                 ...               ...
# 995   996   27  102191.75      Sales 2017-03-24 22:45:01              True
# 996   997   47   64883.57         HR 2022-06-26 00:00:00              True
# 997   998   50   71575.22         HR 2022-06-26 00:00:00              True
# 998   999   28  119242.96         HR 2004-02-27 14:55:17             False
# 999  1000   45  119242.96         HR 2022-06-26 00:00:00              True
#
#      Performance_Score              Rating  Experience_Years  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID                 1000 non-null   int64
#  1   Age                1000 non-null   int32
#  2   Salary             1000 non-null   float64
#  3   Department         1000 non-null   object
#  4   Join_Date          1000 non-null   datetime64[ns]
#  5   Has_Certification  1000 non-null   object
#  6   Performance_Score  1000 non-null   float64
#  7   Rating             755 non-null    object
#  8   Experience_Years   663 non-null    float64
#  9   Remarks            753 non-null    object
# dtypes: datetime64[ns](1), float64(3), int32(1), int64(1), object(4)
# memory usage: 74.3+ KB

# %%
df['Performance_Score'].value_counts()
# Out:
# Performance_Score
# 1.000000    61
# 6.000000    59
# 3.000000    58
# 4.000000    58
# 5.000000    54
#             ..
# 3.258037     1
# 7.334131     1
# 3.406618     1
# 1.828603     1
# 2.142500     1
# Name: count, Length: 520, dtype: int64

# %%
df['Performance_Score']=df['Performance_Score'].round()

# %%
df
# Out:
#        ID  Age     Salary Department           Join_Date Has_Certification  \
# 0       1   45   39382.23  Marketing 2022-06-26 00:00:00              True
# 1       2   45  105639.57         HR 2022-06-26 00:00:00              True
# 2       3   45  105639.57         HR 2014-04-08 16:37:06              True
# 3       4   27   41052.97      Sales 2022-06-26 00:00:00              True
# 4       5   45   51231.54      Sales 2022-06-26 00:00:00              True
# ..    ...  ...        ...        ...                 ...               ...
# 995   996   27  102191.75      Sales 2017-03-24 22:45:01              True
# 996   997   47   64883.57         HR 2022-06-26 00:00:00              True
# 997   998   50   71575.22         HR 2022-06-26 00:00:00              True
# 998   999   28  119242.96         HR 2004-02-27 14:55:17             False
# 999  1000   45  119242.96         HR 2022-06-26 00:00:00              True
#
#      Performance_Score              Rating  Experience_Years  \
# ...

# %%
df
# Out:
#        ID  Age     Salary Department           Join_Date Has_Certification  \
# 0       1   45   39382.23  Marketing 2022-06-26 00:00:00              True
# 1       2   45  105639.57         HR 2022-06-26 00:00:00              True
# 2       3   45  105639.57         HR 2014-04-08 16:37:06              True
# 3       4   27   41052.97      Sales 2022-06-26 00:00:00              True
# 4       5   45   51231.54      Sales 2022-06-26 00:00:00              True
# ..    ...  ...        ...        ...                 ...               ...
# 995   996   27  102191.75      Sales 2017-03-24 22:45:01              True
# 996   997   47   64883.57         HR 2022-06-26 00:00:00              True
# 997   998   50   71575.22         HR 2022-06-26 00:00:00              True
# 998   999   28  119242.96         HR 2004-02-27 14:55:17             False
# 999  1000   45  119242.96         HR 2022-06-26 00:00:00              True
#
#      Performance_Score              Rating  Experience_Years  \
# ...

# %%
df= df.drop(['Rating','split2'], axis = 1)

# %%
df[['split1','split2']] = df['Rating'].str.split('.',expand = True)

# %%
df
# Out:
#        ID  Age     Salary Department   Join_Date Has_Certification  \
# 0       1   45   39382.23  Marketing  2022-06-26              True
# 1       2   45  105639.57         HR  2022-06-26              True
# 2       3   45  105639.57         HR  2014-04-08              True
# 3       4   27   41052.97      Sales  2022-06-26              True
# 4       5   45   51231.54      Sales  2022-06-26              True
# ..    ...  ...        ...        ...         ...               ...
# 995   996   27  102191.75      Sales  2017-03-24              True
# 996   997   47   64883.57         HR  2022-06-26              True
# 997   998   50   71575.22         HR  2022-06-26              True
# 998   999   28  119242.96         HR  2004-02-27             False
# 999  1000   45  119242.96         HR  2022-06-26              True
#
#      Performance_Score  Experience_Years               Remarks split1
# 0                  5.0          9.905266                    21    NaN
# ...

# %%
df['Experience_Years'].value_counts().count()
# Out:
# 362

# %%
df['Experience_Years'].isnull().sum()
# Out:
# 337

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID                 1000 non-null   int64
#  1   Age                1000 non-null   int32
#  2   Salary             1000 non-null   float64
#  3   Department         1000 non-null   object
#  4   Join_Date          1000 non-null   object
#  5   Has_Certification  1000 non-null   object
#  6   Performance_Score  1000 non-null   float64
#  7   Experience_Years   663 non-null    float64
#  8   Remarks            753 non-null    object
#  9   split1             755 non-null    object
# dtypes: float64(3), int32(1), int64(1), object(5)
# memory usage: 74.3+ KB

# %%
df['split1'].value_counts().sum()
# Out:
# 755

# %%
df
# Out:
#        ID  Age     Salary Department   Join_Date Has_Certification  \
# 0       1   45   39382.23  Marketing  2022-06-26              True
# 1       2   45  105639.57         HR  2022-06-26              True
# 2       3   45  105639.57         HR  2014-04-08              True
# 3       4   27   41052.97      Sales  2022-06-26              True
# 4       5   45   51231.54      Sales  2022-06-26              True
# ..    ...  ...        ...        ...         ...               ...
# 995   996   27  102191.75      Sales  2017-03-24              True
# 996   997   47   64883.57         HR  2022-06-26              True
# 997   998   50   71575.22         HR  2022-06-26              True
# 998   999   28  119242.96         HR  2004-02-27             False
# 999  1000   45  119242.96         HR  2022-06-26              True
#
#      Performance_Score  Experience_Years               Remarks split1
# 0                  5.0          9.905266                    21    NaN
# ...

# %%
df.rename(columns = {'split1' : 'Rating'},inplace = True)

# %%
df
# Out:
#        ID  Age     Salary Department   Join_Date Has_Certification  \
# 0       1   45   39382.23  Marketing  2022-06-26              True
# 1       2   45  105639.57         HR  2022-06-26              True
# 2       3   45  105639.57         HR  2014-04-08              True
# 3       4   27   41052.97      Sales  2022-06-26              True
# 4       5   45   51231.54      Sales  2022-06-26              True
# ..    ...  ...        ...        ...         ...               ...
# 995   996   27  102191.75      Sales  2017-03-24              True
# 996   997   47   64883.57         HR  2022-06-26              True
# 997   998   50   71575.22         HR  2022-06-26              True
# 998   999   28  119242.96         HR  2004-02-27             False
# 999  1000   45  119242.96         HR  2022-06-26              True
#
#      Performance_Score  Experience_Years               Remarks Rating
# 0                  5.0          9.905266                    21    NaN
# ...

# %%
columns = df.columns.tolist()

# %%
columns
# Out:
# ['ID',
#  'Age',
#  'Salary',
#  'Department',
#  'Join_Date',
#  'Has_Certification',
#  'Performance_Score',
#  'Experience_Years',
#  'Remarks',
#  'Rating']

# %%
columns.insert(7,columns.pop(columns.index('Rating')))

# %%
df = df[columns]

# %%
df
# Out:
#        ID  Age     Salary Department   Join_Date Has_Certification  \
# 0       1   45   39382.23  Marketing  2022-06-26              True
# 1       2   45  105639.57         HR  2022-06-26              True
# 2       3   45  105639.57         HR  2014-04-08              True
# 3       4   27   41052.97      Sales  2022-06-26              True
# 4       5   45   51231.54      Sales  2022-06-26              True
# ..    ...  ...        ...        ...         ...               ...
# 995   996   27  102191.75      Sales  2017-03-24              True
# 996   997   47   64883.57         HR  2022-06-26              True
# 997   998   50   71575.22         HR  2022-06-26              True
# 998   999   28  119242.96         HR  2004-02-27             False
# 999  1000   45  119242.96         HR  2022-06-26              True
#
#      Performance_Score Rating  Experience_Years               Remarks
# 0                  5.0    NaN          9.905266                    21
# ...

# %%
df['Rating'].unique()
# Out:
# array([nan, 'Poor', 'Good', '1', '4', '3', '2'], dtype=object)

# %%
Rating_map = {
    '1':'Excellent',
    '2':'Average',
    '3':'Satisfactory',
    '4':'unsatisfactory'
}

# %%
df['Rating']= df['Rating'].replace(Rating_map)

# %%
df
# Out:
#        ID  Age     Salary Department   Join_Date Has_Certification  \
# 0       1   45   39382.23  Marketing  2022-06-26              True
# 1       2   45  105639.57         HR  2022-06-26              True
# 2       3   45  105639.57         HR  2014-04-08              True
# 3       4   27   41052.97      Sales  2022-06-26              True
# 4       5   45   51231.54      Sales  2022-06-26              True
# ..    ...  ...        ...        ...         ...               ...
# 995   996   27  102191.75      Sales  2017-03-24              True
# 996   997   47   64883.57         HR  2022-06-26              True
# 997   998   50   71575.22         HR  2022-06-26              True
# 998   999   28  119242.96         HR  2004-02-27             False
# 999  1000   45  119242.96         HR  2022-06-26              True
#
#      Performance_Score     Rating  Experience_Years               Remarks
# 0                  5.0        NaN          9.905266                    21
# ...

# %%
df['Rating'].value_counts().sum()
# Out:
# 755

# %%
df['Rating'].isnull().sum()
# Out:
# 245

# %%
df['Rating']= df['Rating'].fillna('outstanding')

# %%
df
# Out:
#        ID  Age     Salary Department   Join_Date Has_Certification  \
# 0       1   45   39382.23  Marketing  2022-06-26              True
# 1       2   45  105639.57         HR  2022-06-26              True
# 2       3   45  105639.57         HR  2014-04-08              True
# 3       4   27   41052.97      Sales  2022-06-26              True
# 4       5   45   51231.54      Sales  2022-06-26              True
# ..    ...  ...        ...        ...         ...               ...
# 995   996   27  102191.75      Sales  2017-03-24              True
# 996   997   47   64883.57         HR  2022-06-26              True
# 997   998   50   71575.22         HR  2022-06-26              True
# 998   999   28  119242.96         HR  2004-02-27             False
# 999  1000   45  119242.96         HR  2022-06-26              True
#
#      Performance_Score       Rating  Experience_Years               Remarks
# 0                  5.0  outstanding          9.905266                    21
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID                 1000 non-null   int64
#  1   Age                1000 non-null   int32
#  2   Salary             1000 non-null   float64
#  3   Department         1000 non-null   object
#  4   Join_Date          1000 non-null   object
#  5   Has_Certification  1000 non-null   object
#  6   Performance_Score  1000 non-null   float64
#  7   Rating             1000 non-null   object
#  8   Experience_Years   663 non-null    float64
#  9   Remarks            753 non-null    object
# dtypes: float64(3), int32(1), int64(1), object(5)
# memory usage: 74.3+ KB

# %%
df['Experience_Years'].value_counts()
# Out:
# Experience_Years
# 28.000000    14
# 25.000000    14
# 23.000000    14
# 34.000000    14
# 5.000000     13
#              ..
# 34.895783     1
# 8.407679      1
# 20.128817     1
# 18.382519     1
# 24.440936     1
# Name: count, Length: 362, dtype: int64

# %%
df['Experience_Years'].isnull().sum()
# Out:
# 337

# %%
df['Experience_Years']=df['Experience_Years'].round()

# %%
df
# Out:
#        ID  Age     Salary Department   Join_Date Has_Certification  \
# 0       1   45   39382.23  Marketing  2022-06-26              True
# 1       2   45  105639.57         HR  2022-06-26              True
# 2       3   45  105639.57         HR  2014-04-08              True
# 3       4   27   41052.97      Sales  2022-06-26              True
# 4       5   45   51231.54      Sales  2022-06-26              True
# ..    ...  ...        ...        ...         ...               ...
# 995   996   27  102191.75      Sales  2017-03-24              True
# 996   997   47   64883.57         HR  2022-06-26              True
# 997   998   50   71575.22         HR  2022-06-26              True
# 998   999   28  119242.96         HR  2004-02-27             False
# 999  1000   45  119242.96         HR  2022-06-26              True
#
#      Performance_Score       Rating  Experience_Years               Remarks
# 0                  5.0  outstanding              10.0                    21
# ...

# %%
df['Experience_Years']=df['Experience_Years'].fillna(40.0)

# %%
df
# Out:
#        ID  Age     Salary Department   Join_Date Has_Certification  \
# 0       1   45   39382.23  Marketing  2022-06-26              True
# 1       2   45  105639.57         HR  2022-06-26              True
# 2       3   45  105639.57         HR  2014-04-08              True
# 3       4   27   41052.97      Sales  2022-06-26              True
# 4       5   45   51231.54      Sales  2022-06-26              True
# ..    ...  ...        ...        ...         ...               ...
# 995   996   27  102191.75      Sales  2017-03-24              True
# 996   997   47   64883.57         HR  2022-06-26              True
# 997   998   50   71575.22         HR  2022-06-26              True
# 998   999   28  119242.96         HR  2004-02-27             False
# 999  1000   45  119242.96         HR  2022-06-26              True
#
#      Performance_Score       Rating  Experience_Years               Remarks
# 0                  5.0  outstanding              10.0                    21
# ...

# %%
df['Remarks'].value_counts()
# Out:
# Remarks
# Needs Improvement       260
# Exceeds Expectations    260
# 75                        6
# 77                        6
# 19                        6
#                        ...
# 73                        1
# 13                        1
# 63                        1
# 27                        1
# 15                        1
# Name: count, Length: 93, dtype: int64

# %%
df['Remarks'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 1000 entries, 0 to 999
# Series name: Remarks
# Non-Null Count  Dtype
# --------------  -----
# 753 non-null    object
# dtypes: object(1)
# memory usage: 7.9+ KB

# %%
df['Remarks'].value_counts().sum()
# Out:
# 753

# %%
# separate time&date of mixed values in Join_Date into date only by using these code


df['Join_Date'] =df['Join_Date'].dt.date

# %%
df
# Out:
#        ID  Age     Salary Department   Join_Date Has_Certification  \
# 0       1   45   39382.23  Marketing  2022-06-26              True
# 1       2   45  105639.57         HR  2022-06-26              True
# 2       3   45  105639.57         HR  2014-04-08              True
# 3       4   27   41052.97      Sales  2022-06-26              True
# 4       5   45   51231.54      Sales  2022-06-26              True
# ..    ...  ...        ...        ...         ...               ...
# 995   996   27  102191.75      Sales  2017-03-24              True
# 996   997   47   64883.57         HR  2022-06-26              True
# 997   998   50   71575.22         HR  2022-06-26              True
# 998   999   28  119242.96         HR  2004-02-27             False
# 999  1000   45  119242.96         HR  2022-06-26              True
#
#      Performance_Score       Rating  Experience_Years               Remarks
# 0                  5.0  outstanding              10.0                    21
# ...

# %%
#convert numeric string to float values:

def convert_to_numeric(value):
    try:
        return float(value)

    except ValueError:
        return value

# %%
 df['Remarks']= df['Remarks'].apply(convert_to_numeric)

# %%
df
# Out:
#        ID  Age     Salary Department   Join_Date Has_Certification  \
# 0       1   45   39382.23  Marketing  2022-06-26              True
# 1       2   45  105639.57         HR  2022-06-26              True
# 2       3   45  105639.57         HR  2014-04-08              True
# 3       4   27   41052.97      Sales  2022-06-26              True
# 4       5   45   51231.54      Sales  2022-06-26              True
# ..    ...  ...        ...        ...         ...               ...
# 995   996   27  102191.75      Sales  2017-03-24              True
# 996   997   47   64883.57         HR  2022-06-26              True
# 997   998   50   71575.22         HR  2022-06-26              True
# 998   999   28  119242.96         HR  2004-02-27             False
# 999  1000   45  119242.96         HR  2022-06-26              True
#
#      Performance_Score       Rating  Experience_Years               Remarks
# 0                  5.0  outstanding              10.0                  21.0
# ...

# %%
print(df['Remarks'].apply(type))
# Out:
# 0      <class 'float'>
# 1        <class 'str'>
# 2        <class 'str'>
# 3      <class 'float'>
# 4        <class 'str'>
#             ...
# 995      <class 'str'>
# 996      <class 'str'>
# 997      <class 'str'>
# 998      <class 'str'>
# 999      <class 'str'>
# Name: Remarks, Length: 1000, dtype: object

# %%
df['Remarks'].unique()
# Out:
# array([21, 'Exceeds Expectations', nan, 'Needs Improvement', 82, 95, 49,
#        99, 27, 18, 54, 41, 51, 83, 56, 47, 90, 78, 30, 5, 71, 98, 75, 86,
#        24, 10, 14, 89, 2, 37, 94, 91, 63, 26, 11, 62, 58, 42, 74, 13, 65,
#        33, 77, 1, 73, 57, 81, 20, 88, 12, 53, 61, 31, 84, 22, 43, 19, 28,
#        44, 72, 50, 6, 76, 52, 32, 69, 79, 23, 64, 59, 29, 87, 97, 60, 92,
#        34, 4, 17, 80, 8, 25, 38, 9, 55, 3, 35, 40, 36, 70, 66, 48, 68, 85,
#        15], dtype=object)

# %%
#convert the float values into text values

def float_to_text(value):
    if isinstance(value, float):
        if value <= 30.0:
            return 'Needs Significant Improvement'
        elif value <= 60.0:
            return 'Meets Expectations'
        else:
            return 'Exceeds Expectations'
    return value

# %%
df['Remarks']=df['Remarks'].apply(float_to_text)

# %%
df
# Out:
#        ID  Age     Salary Department   Join_Date Has_Certification  \
# 0       1   45   39382.23  Marketing  2022-06-26              True
# 1       2   45  105639.57         HR  2022-06-26              True
# 2       3   45  105639.57         HR  2014-04-08              True
# 3       4   27   41052.97      Sales  2022-06-26              True
# 4       5   45   51231.54      Sales  2022-06-26              True
# ..    ...  ...        ...        ...         ...               ...
# 995   996   27  102191.75      Sales  2017-03-24              True
# 996   997   47   64883.57         HR  2022-06-26              True
# 997   998   50   71575.22         HR  2022-06-26              True
# 998   999   28  119242.96         HR  2004-02-27             False
# 999  1000   45  119242.96         HR  2022-06-26              True
#
#      Performance_Score       Rating  Experience_Years  \
# 0                  5.0  outstanding              10.0
# ...

# %%
df['Remarks'].value_counts()
# Out:
# Remarks
# Exceeds Expectations             612
# Needs Improvement                260
# Meets Expectations                65
# Needs Significant Improvement     63
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID                 1000 non-null   int64
#  1   Age                1000 non-null   int32
#  2   Salary             1000 non-null   float64
#  3   Department         1000 non-null   object
#  4   Join_Date          1000 non-null   object
#  5   Has_Certification  1000 non-null   object
#  6   Performance_Score  1000 non-null   float64
#  7   Rating             1000 non-null   object
#  8   Experience_Years   1000 non-null   float64
#  9   Remarks            1000 non-null   object
# dtypes: float64(3), int32(1), int64(1), object(5)
# memory usage: 74.3+ KB
