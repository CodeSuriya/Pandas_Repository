# %%
#importing pandas

# %%
import pandas as pd

# %%
#data structures in pandas

# %%
#series(1) >> A pandas Series is a one-dimensional labeled array that can hold data of any type

# %%
data = [1, 2, 3, 4]
series = pd.Series(data)  # 'Series' should be capitalized
print(series)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
data = [1,2,3,4]
index = ['a','b','c','d'] # custom index
series = pd.Series(data,index = index) 
print(series)
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
# dataframe(2) >>A pandas Series is a one-dimensional labeled array that can hold data of any type

# %%
data = {'name':['alice','bob','charlie'],'age':[25,30,35]}
df = pd.DataFrame(data)
print(df)
# Out:
#       name  age
# 0    alice   25
# 1      bob   30
# 2  charlie   35

# %%
#importing the excel file (these excel file is used to importing to the pandas not for futher experiment, the other functions are doing only by given example in chatgpt)

# %%
df= pd.read_excel("C:\\Users\\jsuri\\Downloads\\kulturehire\\Kulture Hire submission.xlsx")

# %%
df
# Out:
#                   Date & Time country  Pin Code Gender  \
# 0     2022-12-16 11:46:05.965   India    273005      M
# 1     2022-12-16 11:46:05.965   India    273005      M
# 2     2022-12-16 11:46:05.965   India    273005      M
# 3     2022-12-16 11:46:05.965   India    273005      M
# 4     2022-12-16 11:46:05.965   India    273005      M
# ...                       ...     ...       ...    ...
# 64927 2024-08-21 22:44:11.980   India    700149      M
# 64928 2024-08-21 22:44:11.980   India    700149      M
# 64929 2024-08-21 22:44:11.980   India    700149      M
# 64930 2024-08-21 22:44:11.980   India    700149      M
# 64931 2024-08-21 22:44:11.980   India    700149      M
#
#                 Influencing factors of your career   \
# 0      People who have changed the world for better
# 1      People who have changed the world for better
# 2      People who have changed the world for better
# 3      People who have changed the world for better
# ...

# %%
#exploring data

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64932 entries, 0 to 64931
# Data columns (total 35 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   Date & Time                                          64932 non-null  datetime64[ns]
#  1   country                                              64932 non-null  object
#  2    Pin Code                                            64914 non-null  object
#  3   Gender                                               64932 non-null  object
#  4   Influencing factors of your career                   64932 non-null  object
#  5   pursuing Higher education                            64932 non-null  object
#  6   3+ Years with One Employer                           64932 non-null  object
#  7   Work for Company Without Clear Public Mission        64932 non-null  object
# ...

# %%
#cleaning data

# %%
df.dropna(inplace=True)  # Remove rows with missing value
# Out:
# Empty DataFrame
# Columns: [Date & Time, country,  Pin Code, Gender, Influencing factors of your career , pursuing Higher education, 3+ Years with One Employer, Work for Company Without Clear Public Mission, Work for Company with Misaligned Mission, Work for Company Without Social Impact, Preferred Work Environment, Preferred Employers, Preferred Learning Environment, Closest Career to Your Aspirations, Ideal Manager for You, Preferred Work Setup, Work for Company with Recent Layoffs, Likelihood of Staying 7+ Years with One Employer, Email address, Minimum Expected Monthly Salary (First 3 Years), Minimum Expected Monthly Salary (5 Years Ahead), Work for Company with No-Remote Policy, Minimum Starting Salary Expectation, Preferred Type of Company, Work for Manager with Abusive History, Willing to Work Hours per Day, Frequency of Full Week Breaks for Work-Life Balance, Factors for Work Happiness and Productivity, Work Frustrations,  ,  2,  3,  4,  5,  6]
# Index: []
#
# ...

# %%
 df.fillna(0, inplace=True)  # Fill missing values with 0

# %%
df.drop_duplicates(inplace=True)  # Remove duplicates
# Out:
# Empty DataFrame
# Columns: [Date & Time, country,  Pin Code, Gender, Influencing factors of your career , pursuing Higher education, 3+ Years with One Employer, Work for Company Without Clear Public Mission, Work for Company with Misaligned Mission, Work for Company Without Social Impact, Preferred Work Environment, Preferred Employers, Preferred Learning Environment, Closest Career to Your Aspirations, Ideal Manager for You, Preferred Work Setup, Work for Company with Recent Layoffs, Likelihood of Staying 7+ Years with One Employer, Email address, Minimum Expected Monthly Salary (First 3 Years), Minimum Expected Monthly Salary (5 Years Ahead), Work for Company with No-Remote Policy, Minimum Starting Salary Expectation, Preferred Type of Company, Work for Manager with Abusive History, Willing to Work Hours per Day, Frequency of Full Week Breaks for Work-Life Balance, Factors for Work Happiness and Productivity, Work Frustrations,  ,  2,  3,  4,  5,  6]
# Index: []
#
# ...

# %%
#data filtering

# %%
filtered_df=df[df['age']>30]

# %%
# adding row

# %%
df['salary']=[50000,60000,70000]

# %%
# droping the column

# %%
df.drop('Salary', axis=1, inplace=True)

# %%
# droping the row

# %%
df.drop('Salary', axis=0, inplace=True)

# %%
# droping the particular row (if suppose want to delete the 10th row of the dataframe)

# %%
df.drop(index=9, inplace=True)

# %%
#merging and joining

# %%
df1 = pd.DataFrame({'Name': ['Alice', 'Bob'], 'Age': [25, 30]})
df2 = pd.DataFrame({'Name': ['Alice', 'Bob'], 'Salary': [50000, 60000]})

merged_df = pd.merge(df1, df2, on='Name')  # Merge based on the 'Name' column

# %%
#grouping

# %%
df.groupby('Age').mean()  # Group by a column and calculate the mean
